# %%
import AlgoCrac as ac

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from abc import ABC, abstractmethod
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from functools import partial
import matplotlib.pyplot as plt
import datetime
#from indicators import moving_average, exp_moving_average, vwap
#from Signals import *
from AlgoCrac import moving_average, exp_moving_average, vwap
from AlgoCrac.Signals.Signals import *
from AlgoCrac.Signals.utils import *
from AlgoCrac.Strategy.Strategy import *


from tqdm import tqdm

# %%
timeframe = "5m"
#sym = ['WIX','MMM','GOOGL','TSLA']
sym = ["BDN",'MMM']
sym = ['MMM']
data = ac.get_data(sym, start = "2024-06-12",end="2024-06-13",interval = timeframe)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                            Open        High         Low       Close  \
#                             MMM         MMM         MMM         MMM
# 2024-06-12 09:30:00  102.620003  103.430000  102.510002  103.160004
# 2024-06-12 09:35:00  103.180000  103.360001  102.840103  103.235001
# 2024-06-12 09:40:00  103.250000  103.620003  103.220001  103.555000
# 2024-06-12 09:45:00  103.559998  103.680000  103.129997  103.449997
# 2024-06-12 09:50:00  103.400002  103.419998  102.870003  102.894997
# ...                         ...         ...         ...         ...
# 2024-06-12 15:35:00  100.879997  100.959999  100.809998  100.816902
# 2024-06-12 15:40:00  100.820000  100.930000  100.790001  100.830002
# 2024-06-12 15:45:00  100.808296  101.080002  100.769997  101.039001
# 2024-06-12 15:50:00  101.040001  101.379799  101.019997  101.345596
# 2024-06-12 15:55:00  101.360001  101.404999  101.209999  101.220001
#
#                       Adj Close  Volume
#                             MMM     MMM
# 2024-06-12 09:30:00  103.160004  278959
# 2024-06-12 09:35:00  103.235001  102129
# 2024-06-12 09:40:00  103.555000   80842
# 2024-06-12 09:45:00  103.449997   96051
# 2024-06-12 09:50:00  102.894997   84213
# ...                         ...     ...
# 2024-06-12 15:35:00  100.816902   51592
# 2024-06-12 15:40:00  100.830002   44162
# 2024-06-12 15:45:00  101.039001   59978
# 2024-06-12 15:50:00  101.345596   81371
# 2024-06-12 15:55:00  101.220001  190545
#
# [78 rows x 6 columns]

# %% [markdown]
# Her is a case where a strategy fails, this is due to intraday days with the signal's periods being larger than the number of timesteps within a single trading day.

# %%
period = 120
indicator =  "SMA"
buy_signal = Crossover(period, indicator = indicator, on = "Close", invert = False, eps = 0.2)
sell_signal = Crossover(period, indicator = indicator, on = "Close", invert = True, eps = 0.2)

st = Strategy(buy_signal, sell_signal,
              timeframe=timeframe,
                trade_allocation = 1000,
                  allocation = 10000,
                    negative_allocation= False,
                      side = 'long')
# Out:
# Error: period of the signal is too large for intraday strategy, strategy is not initialized

# %%
range = Range(max_val = 95,
                         min_val = 85,
                        metric = "last",
                        in_range = True, 
                        on = "Close", # Open, High, Low, Close, Volume
                        invert = False,
                        )



signal_list = [range]
#signal_list = [vwap_crossover]
#signal_list = [v_crossover]

#signal_list = [ ema_crossover]
ma_confl = Confluence(signals_list = signal_list, max_signals = 3, invert = False)

buy_signal = ma_confl
buy_signal.plot_signals(data, signal_type = 'con')

sell_signal = Confluence(signals_list = signal_list, max_signals = 3, invert = True)

sell_signal.plot_signals(data, signal_type = 'con')
# Out:
# plot intraday data
# plot intraday data

# %%
st = Strategy(buy_signal, sell_signal,
              timeframe=timeframe,
                trade_allocation = 1000,
                  allocation = 10000,
                    negative_allocation= False,
                      side = 'long')

# %% [markdown]
# ## Backtest

# %%
st.reset()
bt = Backtest(st, data, fast = False, include_commission= True)
a = bt.run()  
bt.summary()
# Out:
# 100%|██████████| 74/74 [00:00<00:00, 404.52it/s]
# Total time strategy update:  0.16695880889892578
# Total time status update:  0.01202702522277832
#        allocation total reward total commission avg reward std reward  \
# closed          0            0                0          0          0
# all             0            0                0          0          0
#
#        sharpe ratio % reward avg risk reward ratio avg duration (min)  \
# closed            0        0                     0                  0
# all               0        0                     0                  0
#
#        max drawdown num trades win rate
# closed            0          0        0
# all               0          0        0

# %% [markdown]
# * -all- refers to the status at any given time (open and closed trades)
# * -closed- refers only to closed trades

# %% [markdown]
# bt.status

# %%
bt.strategy.closed_trades
# Out:
# Empty DataFrame
# Columns: [reward]
# Index: []

# %% [markdown]
# ## Fast backtest

# %%
st.reset()
bt = Backtest(st, data, fast = True, include_commission= True)
a = bt.run()  
bt.summary()
# Out:
# [datetime.date(2024, 6, 12)]
# Total time strategy update:  0.004021644592285156
# Total time status update:  0.0
#        allocation total reward total commission avg reward std reward  \
# closed          0            0                0          0          0
# all             0            0                0          0          0
#
#        sharpe ratio % reward avg risk reward ratio avg duration (min)  \
# closed            0        0                     0                  0
# all               0        0                     0                  0
#
#        max drawdown num trades win rate
# closed            0          0        0
# all               0          0        0

# %%
symbol_summary = bt.strategy.closed_trades[['symbol','reward']].groupby('symbol').sum().copy()
symbol_summary['reward (average)'] = bt.strategy.closed_trades[['symbol','reward']].groupby('symbol').mean()
symbol_summary
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 symbol_summary = bt.strategy.closed_trades[['symbol','reward']].groupby('symbol').sum().copy()
#       2 symbol_summary['reward (average)'] = bt.strategy.closed_trades[['symbol','reward']].groupby('symbol').mean()
#       3 symbol_summary
#
# File c:\Users\liran\anaconda3\envs\algocrac\lib\site-packages\pandas\core\frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\liran\anaconda3\envs\algocrac\lib\site-packages\pandas\core\indexes\base.py:6113, in Index._get_indexer_strict(self, key, axis_name)
#    6110 else:
#    6111     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6113 self._raise_if_missing(keyarr, indexer, axis_name)
#    6115 keyarr = self.take(indexer)
#    6116 if isinstance(key, Index):
#    6117     # GH 42790 - Preserve name from an Index
#
# File c:\Users\liran\anaconda3\envs\algocrac\lib\site-packages\pandas\core\indexes\base.py:6176, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6173     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6175 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6176 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['symbol'] not in index"

# %%
bt.strategy.closed_trades
# Out:
#   entry time  entry date exit time   exit date  entry price  exit price  \
# 0   13:20:00  2024-06-12  13:25:00  2024-06-12   101.510002  101.529999
# 1   13:35:00  2024-06-12  13:45:00  2024-06-12   101.570000  101.425003
# 2   15:05:00  2024-06-12  15:10:00  2024-06-12   101.105003  101.169998
# 3   15:50:00  2024-06-12  15:55:00  2024-06-12   101.040001  101.360001
#
#   symbol    reward  position  commission  market value  id
# 0    MMM  0.179970         9         1.5    913.769989   0
# 1    MMM -1.304970         9         1.5    912.825027   1
# 2    MMM  0.584953         9         1.5    910.529984   2
# 3    MMM  2.879997         9         1.5    912.240005   3

# %%
bt.strategy.open_trades
# Out:
# Empty DataFrame
# Columns: [reward]
# Index: []

# %%
pd.concat([bt.strategy.closed_trades.head(),bt.strategy.open_trades.head()], ignore_index=True)
# Out:
#   entry time  entry date exit time   exit date  entry price  exit price  \
# 0   13:20:00  2024-06-12  13:25:00  2024-06-12   101.510002  101.529999
# 1   13:35:00  2024-06-12  13:45:00  2024-06-12   101.570000  101.425003
# 2   15:05:00  2024-06-12  15:10:00  2024-06-12   101.105003  101.169998
# 3   15:50:00  2024-06-12  15:55:00  2024-06-12   101.040001  101.360001
#
#   symbol    reward  position  commission  market value   id
# 0    MMM  0.179970       9.0         1.5    913.769989  0.0
# 1    MMM -1.304970       9.0         1.5    912.825027  1.0
# 2    MMM  0.584953       9.0         1.5    910.529984  2.0
# 3    MMM  2.879997       9.0         1.5    912.240005  3.0
