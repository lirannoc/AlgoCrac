# %% [markdown]
# ### Tutorial 1 - Data
# Welcome to AlgoCrac, a framework for algorithmic trading, aiming for easy implementing, research and broker connectivity. In this tutorial will provide you a walkthrough in the building blocks of AlgoCrac.
#
# ### Data
# In this notebook we'll provide a quick introduction to importing stock data. As of today, AlgoCrac can only import stock market data from yahoo finance (yfinance).
# The data is imported (scraped) from the yahoo finance website, and in future version we'll support broker connectivity where broker data will also be permitted.
#
# algocrac supports 1D, 4H, 1H, 30m, 15m, 5m and 1m data intervals.
#
# data access history in yfinance:
# 1D stock data - no history limits

# %%
from AlgoCrac import *

# %% [markdown]
# Let's import wix stocks from the last 10 years

# %%
sym = ["TSLA"]
data = get_data(sym, start = "2010-03-08",end="2023-05-20",interval = '1D')
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close Adj Close     Volume
#                 TSLA      TSLA      TSLA      TSLA      TSLA       TSLA
# 2010-06-29  1.266667  1.666667  1.169333  1.592667  1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667  1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000  1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000  1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000  1.074000  103003500

# %% [markdown]
# Let's import Wix,Tesla and Netflix stocks from the last 5 days with a 5m interval.

# %%
sym = ["TEVA","TSLA","NFLX"]
data = get_data(sym, start = "2023-01-23",end="2023-01-28",interval = '1H')
data.head()
# Out:
# [*********************100%***********************]  3 of 3 completed
#                       Adj Close                           Close          \
#                            NFLX    TEVA        TSLA        NFLX    TEVA
# 2023-01-23 09:30:00  354.170013  10.305  138.789993  354.170013  10.305
# 2023-01-23 10:30:00  357.595001  10.345  140.570007  357.595001  10.345
# 2023-01-23 11:30:00  358.779999  10.380  142.039993  358.779999  10.380
# 2023-01-23 12:30:00  360.983185  10.405  143.740005  360.983185  10.405
# 2023-01-23 13:30:00  360.829987  10.405  144.009995  360.829987  10.405
#
#                                        High                             Low  \
#                            TSLA        NFLX    TEVA        TSLA        NFLX
# 2023-01-23 09:30:00  138.789993  354.771698  10.430  139.699997  340.632904
# 2023-01-23 10:30:00  140.570007  360.730011  10.395  141.550003  352.850006
# 2023-01-23 11:30:00  142.039993  360.239990  10.380  142.419998  356.200012
# ...

# %%
SandP500 = get_SandP500_data(start = "2023-05-01",end="2023-05-28",interval = '1D')
# Out:
# [*********************100%***********************]  503 of 503 completed
#
# 5 Failed downloads:
# - VLTO: Data doesn't exist for startDate = 1682913600, endDate = 1685246400
# - BF.B: No data found for this date range, symbol may be delisted
# - BRK.B: No timezone found, symbol may be delisted
# - GEV: Data doesn't exist for startDate = 1682913600, endDate = 1685246400
# - SOLV: Data doesn't exist for startDate = 1682913600, endDate = 1685246400

# %%
# warning - this will take a while to run

# nasdaq 100 dataet_SandP500_data
SandP500 = get_SandP500_data(start = "2023-05-01",end="2023-05-28",interval = '1D')

# nasdaq 100 data
nasdaq100 = get_nasdaq100_data(start = "2023-05-01",end="2023-05-28",interval = '1D')

# nasdaq composite data
nasdaq = get_nasdaq_data(start = "2023-05-01",end="2023-05-28",interval = '1D')

# nyse data
nyse = get_nyse_data(start = "2023-05-01",end="2023-05-28",interval = '1D')
# Out:
# [*********************100%***********************]  503 of 503 completed
#
# 5 Failed downloads:
# - VLTO: Data doesn't exist for startDate = 1682913600, endDate = 1685246400
# - BF.B: No data found for this date range, symbol may be delisted
# - BRK.B: No timezone found, symbol may be delisted
# - GEV: Data doesn't exist for startDate = 1682913600, endDate = 1685246400
# - SOLV: Data doesn't exist for startDate = 1682913600, endDate = 1685246400
# [*********************100%***********************]  101 of 101 completed
# last update for symbol names: 11/02/2023
# [*********************100%***********************]  4673 of 4673 completed
#
# 1273 Failed downloads:
# - GRCYW: Period 'max' is invalid, must be one of ['1d', '5d']
# - BTWN: No data found, symbol may be delisted
# - JMACU: No data found, symbol may be delisted
# - ACER: No data found, symbol may be delisted
# - DCRDW: No timezone found, symbol may be delisted
# - JUGGU: No data found, symbol may be delisted
# ...
